# %% [markdown]
# A Model To Predict the Loan Status

# %%
# Importing necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Loading the dataset
loan_df = pd.read_csv('loan-data-preprocessing.csv')

# %%
# Seperating the dataset for the model since we need only the amount in EUR
loan_model = loan_df.iloc[:, [2, 4, 5, 7, 9, 11, 12, 13, 14, 15, 16]]

# %%
loan_model
# Out:
#       loan_amnt_EUR  funded_amnt_EUR  int_rate  installment_EUR  \
# 0       9038.082814       908.350032      18.0       327.006011
# 1      10900.200379     10900.200379      20.0       294.305410
# 2       8924.299805      8924.299805      13.0       303.426193
# 3      24707.120859     24707.120859      28.0       502.317567
# 4      10526.076489     10526.076489      28.0       347.175856
# ...             ...              ...       ...              ...
# 9995   12804.119629     12804.119629      28.0       385.038169
# 9996   18291.599470     18291.599470      28.0       577.099963
# 9997    5121.647852      5121.647852      28.0       164.624395
# 9998    3658.319894      3658.319894      28.0       119.809977
# 9999   19754.927428     19754.927428      28.0       609.110262
#
#       total_pymnt_EUR  issue_data  loan_status  term_month  sub_grade  \
# 0          973.751234        10.0          1.0        36.0       21.0
# ...

# %%
# spliting the data into train and test data

train_data, test_data = train_test_split(loan_df, test_size = 0.2, random_state = 42)

# %%
# Creating an instant of Logistic Regression
logreg = LogisticRegression()

# %%
# Seperating the target variable ('survived') fron the rest of the trianing data
x_train = train_data.drop('loan_status', axis = 1)
y_train = train_data['loan_status']

# %%
# Training the data with Logistic Regression model

logreg.fit(x_train, y_train)
# Out:
# C:\Users\davsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Seperating the  target varable and the rest of the testing data
x_test = test_data.drop('loan_status', axis = 1)
y_test = test_data['loan_status']

# %%
# Predicting with the Logistic Regression model
prediction = logreg.predict(x_test)

# %%
# Classification Report
print('Classification Report:\n ', classification_report(y_test, prediction))
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       118
#          1.0       0.94      1.00      0.97      1882
#
#     accuracy                           0.94      2000
#    macro avg       0.47      0.50      0.48      2000
# weighted avg       0.89      0.94      0.91      2000
# C:\Users\davsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\davsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Confussion Matrix
print('Confusion Matrix:\n ', confusion_matrix(y_test, prediction))
# Out:
# Confusion Matrix:
#   [[   0  118]
#  [   0 1882]]

# %%
# Accuracy Score
print('Accuracy Score:\n ', accuracy_score(y_test, prediction))
# Out:
# Accuracy Score:
#   0.941
